# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaShan-cyber/GUVI-Project-2/blob/main/GUVI_PROJECT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data1 = pd.read_csv('Stores.csv')
print(data1.head())
print(data1.info())
print(data1.describe())
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  01-01-2008
# 1  01-12-2008
# 2  01-07-2012
# 3  01-01-2010
# 4  12-09-2015
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# ...

# %%
data1
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#      Open Date
# 0   01-01-2008
# 1   01-12-2008
# 2   01-07-2012
# 3   01-01-2010
# ...

# %%
print(data1.isnull().sum())
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
duplicates = data1.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
data1['category_column'] = data1['category_column'].str.lower().str.strip()

# %%
import pandas as pd
data1 = pd.read_csv('Stores.csv')
data1['Open Date'] = data1['Open Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
data1['Open Date'] = data1['Open Date'].dt.strftime('%d-%m-%Y')
# Out:
# <ipython-input-78-f6d058d112d3>:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data1['Open Date'] = data1['Open Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))

# %%
data1
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#      Open Date
# 0   01-01-2008
# 1   12-01-2008
# 2   07-01-2012
# 3   01-01-2010
# ...

# %%
print(data1.columns)
# Out:
# Index(['StoreKey', 'Country', 'State', 'Square Meters', 'Open Date'], dtype='object')

# %%
print(data1.isnull().sum())
print(data1.info())
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB
# None

# %%
data1.to_csv('cleaned_Stores.csv', index=False)

# %%
## NEXT DATA FRAME df2 - Customers

# %%
import pandas as pd
df2 = pd.read_csv('Customers.csv', encoding='latin1')
print(df2.head())
print(df2.info())
print(df2.describe())
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  07-03-1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
df2
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
print(df2.isnull().sum())
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
import pandas as pd
df2 = pd.read_csv('Customers.csv', encoding='latin1')
df2['Birthday'] = df2['Birthday'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
df2['Birthday'] = df2['Birthday'].dt.strftime('%d-%m-%Y')
# Out:
# <ipython-input-75-cb1e2e25d57a>:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df2['Birthday'] = df2['Birthday'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))

# %%
print(df2[['State Code','State']])
null_state_codes = df2[df2['State Code'].isnull()]
print(null_state_codes[['State Code','State']])
# Out:
#       State Code              State
# 0             SA    South Australia
# 1             WA  Western Australia
# 2            VIC           Victoria
# 3             SA    South Australia
# 4            VIC           Victoria
# ...          ...                ...
# 15261         TX              Texas
# 15262         VA           Virginia
# 15263         NC     North Carolina
# 15264         CA         California
# 15265         MI           Michigan
#
# [15266 rows x 2 columns]
#      State Code   State
# 5304        NaN  Napoli
# 5316        NaN  Napoli
# 5372        NaN  Napoli
# 5377        NaN  Napoli
# 5378        NaN  Napoli
# 5485        NaN  Napoli
# 5525        NaN  Napoli
# 5531        NaN  Napoli
# 5631        NaN  Napoli
# 5695        NaN  Napoli

# %%
df2['State Code'] = df2['State Code'].fillna(df2['State'].map({'Napoli': 'NAP'}))

# %%
print(df2.isnull().sum())
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
duplicates = df2.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
df2['City'] = df2['City'].str.lower().str.strip().str.title()

# %%
df2
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       Wandearah East         SA
# 1              325  Female       Madison Hull           Mount Budd         WA
# 2              554  Female      Claire Ferres            Winjallok        VIC
# 3              786    Male  Jai Poltpalingada         Middle River         SA
# 4             1042    Male    Aidan Pankhurst        Tawonga South        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df2.to_csv('cleaned_Customers.csv', index=False)

# %%
## NEXT DATA FRAME df3 - Exchange_Rates

# %%
import pandas as pd
df3 = pd.read_csv('Exchange_Rates.csv')
print(df3.head())
print(df3.info())
print(df3.describe())
# Out:
#          Date Currency  Exchange
# 0  01-01-2015      USD    1.0000
# 1  01-01-2015      CAD    1.1583
# 2  01-01-2015      AUD    1.2214
# 3  01-01-2015      EUR    0.8237
# 4  01-01-2015      GBP    0.6415
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB
# None
#            Exchange
# count  11215.000000
# mean       1.061682
# std        0.245519
# min        0.628500
# 25%        0.857800
# 50%        1.000000
# 75%        1.311900
# max        1.725300

# %%
print(df3.isnull().sum())
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
df3
# Out:
#              Date Currency  Exchange
# 0      01-01-2015      USD    1.0000
# 1      01-01-2015      CAD    1.1583
# 2      01-01-2015      AUD    1.2214
# 3      01-01-2015      EUR    0.8237
# 4      01-01-2015      GBP    0.6415
# ...           ...      ...       ...
# 11210   2/20/2021      USD    1.0000
# 11211   2/20/2021      CAD    1.2610
# 11212   2/20/2021      AUD    1.2723
# 11213   2/20/2021      EUR    0.8238
# 11214   2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
import pandas as pd
df3 = pd.read_csv('Exchange_Rates.csv')
df3['Date'] = df3['Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
df3['Date'] = df3['Date'].dt.strftime('%d-%m-%Y')
# Out:
# <ipython-input-27-6a561d4384f5>:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df3['Date'] = df3['Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))

# %%
duplicates = df3.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
df3.rename(columns={'Currency': 'Currency Code'}, inplace=True)

# %%
df3
# Out:
#              Date Currency Code  Exchange
# 0      01-01-2015           USD    1.0000
# 1      01-01-2015           CAD    1.1583
# 2      01-01-2015           AUD    1.2214
# 3      01-01-2015           EUR    0.8237
# 4      01-01-2015           GBP    0.6415
# ...           ...           ...       ...
# 11210  20-02-2021           USD    1.0000
# 11211  20-02-2021           CAD    1.2610
# 11212  20-02-2021           AUD    1.2723
# 11213  20-02-2021           EUR    0.8238
# 11214  20-02-2021           GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df3.to_csv('cleaned_Exchange_Rates.csv', index=False)

# %%
## NEXT DATA FRAME df4 - Products

# %%
import pandas as pd
df4 = pd.read_csv('Products.csv')
print(df4.head())
print(df4.info())
print(df4.describe())
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
print(df4.isnull().sum())
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
duplicates = df4.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
import matplotlib.pyplot as plt
plt.boxplot(df4['CategoryKey'])
plt.show()#baseline is 4

# %%
import matplotlib.pyplot as plt
plt.boxplot(df4['SubcategoryKey'])
plt.show()#baseline is 400

# %%
df4
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
df4.to_csv('cleaned_Products.csv', index=False)

# %%
## NEXT DATA FRAME df5 - SALES.2

# %%
import pandas as pd
df5 = pd.read_csv('Sales.2.csv')
print(df5.head())
print(df5.info())
print(df5.describe())
# Out:
#    Order Number  Line Item  Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1  01-01-2016           NaN       265598        10
# 1        366001          1  01-01-2016     1/13/2016      1269051         0
# 2        366001          2  01-01-2016     1/13/2016      1269051         0
# 3        366002          1  01-01-2016    01-12-2016       266019         0
# 4        366002          2  01-01-2016    01-12-2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
# ...

# %%
print(df5.isnull().sum())
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
duplicates = df5.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
import pandas as pd#CONVERTING ORDER DATES TO THE FORMAT
df5 = pd.read_csv('Sales.2.csv')
df5['Order Date'] = df5['Order Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
df5['Order Date'] = df5['Order Date'].dt.strftime('%d-%m-%Y')
print(df5[['Order Date']])
# Out:
# <ipython-input-148-334437c6d4bd>:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df5['Order Date'] = df5['Order Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
#        Order Date
# 0      01-01-2016
# 1      01-01-2016
# 2      01-01-2016
# 3      01-01-2016
# 4      01-01-2016
# ...           ...
# 62879  20-02-2021
# 62880  20-02-2021
# 62881  20-02-2021
# 62882  20-02-2021
# 62883  20-02-2021
#
# [62884 rows x 1 columns]

# %%
df5['Order Date'] = pd.to_datetime(df5['Order Date'], errors='coerce', infer_datetime_format=True)
print("After conversion to datetime:")
print(df5['Order Date'])
df5['Order Date'] = df5['Order Date'].dt.strftime('%d-%m-%Y')
print("\nFormatted Order Date:")
print(df5['Order Date'])
# Out:
# After conversion to datetime:
# 0       2016-01-01
# 1       2016-01-01
# 2       2016-01-01
# 3       2016-01-01
# 4       2016-01-01
#            ...
# 62879          NaT
# 62880          NaT
# 62881          NaT
# 62882          NaT
# 62883          NaT
# Name: Order Date, Length: 62884, dtype: datetime64[ns]
#
# Formatted Order Date:
# 0        01-01-2016
# 1        01-01-2016
# 2        01-01-2016
# 3        01-01-2016
# 4        01-01-2016
#             ...
# 62879           NaN
# 62880           NaN
# 62881           NaN
# 62882           NaN
# 62883           NaN
# Name: Order Date, Length: 62884, dtype: object
# <ipython-input-149-f7ee4ab09020>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
# ...

# %%
import pandas as pd#CONVERTING DELIVERY DATES TO THE FORMAT
df5 = pd.read_csv('Sales.2.csv')
df5['Delivery Date'] = df5['Delivery Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
df5['Delivery Date'] = df5['Delivery Date'].dt.strftime('%d-%m-%Y')
print(df5[['Delivery Date']])
# Out:
# <ipython-input-150-2ffe5c85264a>:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df5['Delivery Date'] = df5['Delivery Date'].apply(lambda x:pd.to_datetime(x, infer_datetime_format=True))
#       Delivery Date
# 0               NaN
# 1        13-01-2016
# 2        13-01-2016
# 3        12-01-2016
# 4        12-01-2016
# ...             ...
# 62879           NaN
# 62880    24-02-2021
# 62881    23-02-2021
# 62882    23-02-2021
# 62883    23-02-2021
#
# [62884 rows x 1 columns]

# %%
print(df5['Delivery Date'].head())
# Out:
# 0           NaN
# 1    13-01-2016
# 2    13-01-2016
# 3    12-01-2016
# 4    12-01-2016
# Name: Delivery Date, dtype: object

# %%
print(df5['Delivery Date'].dtype)
# Out:
# object

# %%
df5['Delivery Date'] = pd.to_datetime(df5['Delivery Date'], errors='coerce', infer_datetime_format=True)
print("After conversion to datetime:")
print(df5['Delivery Date'])
df5['Delivery Date'] = df5['Delivery Date'].dt.strftime('%d-%m-%Y')
print("\nFormatted Delivery Date:")
print(df5['Delivery Date'])
# Out:
# After conversion to datetime:
# 0              NaT
# 1       2016-01-13
# 2       2016-01-13
# 3       2016-01-12
# 4       2016-01-12
#            ...
# 62879          NaT
# 62880   2021-02-24
# 62881   2021-02-23
# 62882   2021-02-23
# 62883   2021-02-23
# Name: Delivery Date, Length: 62884, dtype: datetime64[ns]
#
# Formatted Delivery Date:
# 0               NaN
# 1        13-01-2016
# 2        13-01-2016
# 3        12-01-2016
# 4        12-01-2016
#             ...
# 62879           NaN
# 62880    24-02-2021
# 62881    23-02-2021
# 62882    23-02-2021
# 62883    23-02-2021
# Name: Delivery Date, Length: 62884, dtype: object
# <ipython-input-153-e423cdf1aebe>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
# ...

# %%
#ANALYSING THE MEAN AND MEDIAN OF DELIVERY TIME
df5['Order Date'] = pd.to_datetime(df5['Order Date'], format='%d-%m-%Y', errors='coerce')
df5['Delivery Date'] = pd.to_datetime(df5['Delivery Date'], format='%d-%m-%Y', errors='coerce')
df5['Delivery Time'] = (df5['Delivery Date'] - df5['Order Date']).dt.days
mean_delivery_time = df5['Delivery Time'].mean()
median_delivery_time = df5['Delivery Time'].median()
print(f"Mean Delivery Time: {mean_delivery_time}")
print(f"Median Delivery Time: {median_delivery_time}")
# Out:
# Mean Delivery Time: 1.0617999227500965
# Median Delivery Time: 3.0

# %%
#ANALYSING THE MISSING DELIVERY DATE WITH RESPECT TO CURRENCY
missing_count = df5['Delivery Date'].isnull().sum()
missing_percentage = (missing_count / len(df5)) * 100
missing_by_currency = df5[df5['Delivery Date'].isnull()].groupby('Currency Code').size()
print(f"Number of missing values in Delivery Date: {missing_count}")
print(f"Percentage of missing values in Delivery Date: {missing_percentage:.2f}%")
print("Number of missing values by Currency Code:")
print(missing_by_currency)
# Out:
# Number of missing values in Delivery Date: 49719
# Percentage of missing values in Delivery Date: 79.06%
# Number of missing values by Currency Code:
# Currency Code
# AUD     2248
# CAD     4206
# EUR    10067
# GBP     6643
# USD    26555
# dtype: int64

# %%
print(df5.isnull().sum())
print(df5.info())
# Out:
# Order Number         0
# Line Item            0
# Order Date       38540
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# Delivery Time    57706
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     24344 non-null  datetime64[ns]
#  3   Delivery Date  13165 non-null  datetime64[ns]
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
#  9   Delivery Time  5178 non-null   float64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(1)
# ...

# %%
print(df5[['Order Date','Delivery Date']])
null_state_codes = df5[df5['Delivery Date'].isnull()]
print(null_state_codes[['Order Date','Delivery Date']])
# Out:
#        Order Date Delivery Date
# 0      01-01-2016           NaN
# 1      01-01-2016    13-01-2016
# 2      01-01-2016    13-01-2016
# 3      01-01-2016    12-01-2016
# 4      01-01-2016    12-01-2016
# ...           ...           ...
# 62879   2/20/2021           NaN
# 62880   2/20/2021    24-02-2021
# 62881   2/20/2021    23-02-2021
# 62882   2/20/2021    23-02-2021
# 62883   2/20/2021    23-02-2021
#
# [62884 rows x 2 columns]
#        Order Date Delivery Date
# 0      01-01-2016           NaN
# 6      01-01-2016           NaN
# 7      01-01-2016           NaN
# 8      01-01-2016           NaN
# 9      01-01-2016           NaN
# ...           ...           ...
# 62867   2/20/2021           NaN
# 62868   2/20/2021           NaN
# 62869   2/20/2021           NaN
# 62872   2/20/2021           NaN
# 62879   2/20/2021           NaN
#
# [49719 rows x 2 columns]

# %%
print(df5.head())
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01           NaT       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051         0
# 2        366001          2 2016-01-01    2016-01-13      1269051         0
# 3        366002          1 2016-01-01    2016-01-12       266019         0
# 4        366002          2 2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code  Delivery Time
# 0        1304         1           CAD            NaN
# 1        1048         2           USD           12.0
# 2        2007         1           USD           12.0
# 3        1106         7           CAD           11.0
# 4         373         1           CAD           11.0

# %%
print(df4.head())
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
import pandas as pd
df5 = pd.read_csv('cleaned_Sales.csv')
df2 = pd.read_csv('cleaned_Customers.csv')
data1 = pd.read_csv('cleaned_Stores.csv')
df3 = pd.read_csv('cleaned_Exchange_Rates.csv')
df4 = pd.read_csv('cleaned_Products.csv')


merged_df = df5.merge(df3, on='Currency Code', how='outer') \
                .merge(df2, on='CustomerKey', how='outer') \
                .merge(data1, on='StoreKey', how='outer') \
                .merge(df4, on='ProductKey', how='outer')
merged_df = merged_df.reset_index(drop=True)

# %%
print(df3.head())
# Out:
#          Date Currency  Exchange
# 0  01-01-2015      USD    1.0000
# 1  01-01-2015      CAD    1.1583
# 2  01-01-2015      AUD    1.2214
# 3  01-01-2015      EUR    0.8237
# 4  01-01-2015      GBP    0.6415

# %%
print(df2.head())
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  Wandearah East         SA
# 1          325  Female       Madison Hull      Mount Budd         WA
# 2          554  Female      Claire Ferres       Winjallok        VIC
# 3          786    Male  Jai Poltpalingada    Middle River         SA
# 4         1042    Male    Aidan Pankhurst   Tawonga South        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  03-07-1939
# 1  Western Australia     6522  Australia  Australia  27-09-1979
# 2           Victoria     3380  Australia  Australia  26-05-1947
# 3    South Australia     5223  Australia  Australia  17-09-1957
# 4           Victoria     3698  Australia  Australia  19-11-1965

# %%
print(data1.head())
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  01-01-2008
# 1  12-01-2008
# 2  07-01-2012
# 3  01-01-2010
# 4  09-12-2015

# %%
#product key, customer key,

# %%
df5
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1        NaT           NaT      1216913
# 62880       2243031          1        NaT    2021-02-24       511229
# 62881       2243032          1        NaT    2021-02-23       331277
# 62882       2243032          2        NaT    2021-02-23       331277
# 62883       2243032          3        NaT    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Delivery Time
# 0            10        1304         1           CAD            NaN
# ...

# %%
df5.to_csv('cleaned_Sales.csv', index=False)

# %%
#MERGING

merged_sales_products = pd.merge(sales_data, products_data, on='product_id', how='inner')
